# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

## Modelling
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor, BaggingRegressor
from sklearn.model_selection import train_test_split, KFold, cross_val_score, learning_curve
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
frequency_domain_features_train = pd.read_csv('frequency_domain_features_train.csv')

# %%
heart_rate_non_linear_features_train = pd.read_csv('heart_rate_non_linear_features_train.csv')

# %%
time_domain_features_train = pd.read_csv('time_domain_features_train.csv')

# %%
print(frequency_domain_features_train.shape)
print(heart_rate_non_linear_features_train.shape)
print(time_domain_features_train.shape)
# Out:
# (369289, 12)
# (369289, 7)
# (369289, 20)

# %%
data_train_temp = pd.merge(frequency_domain_features_train,heart_rate_non_linear_features_train, on = 'uuid')
print(data_train_temp.shape)
# Out:
# (369289, 18)

# %%
data_train = pd.merge(data_train_temp,time_domain_features_train, on = 'uuid')
print(data_train.shape)
# Out:
# (369289, 37)

# %%
data_train.head()
# Out:
#                                    uuid          VLF    VLF_PCT           LF  \
# 0  89df2855-56eb-4706-a23b-b39363dd605a  2661.894136  72.203287  1009.249419
# 1  80c795e4-aa56-4cc0-939c-19634b89cbb2  2314.265450  76.975728   690.113275
# 2  c2d5d102-967c-487d-88f2-8b005a449f3e  1373.887112  51.152225  1298.222619
# 3  37eabc44-1349-4040-8896-0d113ad4811f  2410.357408  70.180308  1005.981659
# 4  aa777a6a-7aa3-4f6e-aced-70f8691dd2b7  1151.177330  43.918366  1421.782051
#
#       LF_PCT      LF_NU         HF    HF_PCT     HF_NU           TP  ...  \
# 0  27.375666  98.485263  15.522603  0.421047  1.514737  3686.666157  ...
# 1  22.954139  99.695397   2.108525  0.070133  0.304603  3006.487251  ...
# 2  48.335104  98.950472  13.769729  0.512671  1.049528  2685.879461  ...
# 3  29.290305  98.224706  18.181913  0.529387  1.775294  3434.520980  ...
# 4  54.242160  96.720007  48.215822  1.839473  3.279993  2621.175204  ...
#
#        KURT      SKEW  MEAN_REL_RR  MEDIAN_REL_RR  SDRR_REL_RR  RMSSD_REL_RR  \
# 0 -0.856554  0.335218    -0.000203      -0.000179     0.017080      0.007969
# 1 -0.408190 -0.155286    -0.000059       0.000611     0.013978      0.004769
# 2  0.351789 -0.656813    -0.000011      -0.000263     0.018539      0.008716
# 3 -0.504947 -0.386138     0.000112       0.000494     0.017761      0.008660
# 4 -0.548408 -0.154252    -0.000100      -0.002736     0.023715      0.013055
#
#    SDSD_REL_RR SDRR_RMSSD_REL_RR  KURT_REL_RR  SKEW_REL_RR
# 0     0.007969          2.143342    -0.856554     0.335218
# 1     0.004769          2.930855    -0.408190    -0.155286
# 2     0.008716          2.127053     0.351789    -0.656813
# 3     0.008660          2.050988    -0.504947    -0.386138
# 4     0.013055          1.816544    -0.548408    -0.154252
#
# [5 rows x 37 columns]

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369289 entries, 0 to 369288
# Data columns (total 37 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   uuid               369289 non-null  object
#  1   VLF                369289 non-null  float64
#  2   VLF_PCT            369289 non-null  float64
#  3   LF                 369289 non-null  float64
#  4   LF_PCT             369289 non-null  float64
#  5   LF_NU              369289 non-null  float64
#  6   HF                 369289 non-null  float64
#  7   HF_PCT             369289 non-null  float64
#  8   HF_NU              369289 non-null  float64
#  9   TP                 369289 non-null  float64
#  10  LF_HF              369289 non-null  float64
#  11  HF_LF              369289 non-null  float64
#  12  SD1                369289 non-null  float64
#  13  SD2                369289 non-null  float64
#  14  sampen             369289 non-null  float64
#  15  higuci             369289 non-null  float64
#  16  datasetId          369289 non-null  int64
#  17  condition          369289 non-null  object
#  18  MEAN_RR            369289 non-null  float64
#  19  MEDIAN_RR          369289 non-null  float64
#  20  SDRR               369289 non-null  float64
#  21  RMSSD              369289 non-null  float64
#  22  SDSD               369289 non-null  float64
#  23  SDRR_RMSSD         369289 non-null  float64
#  24  HR                 369289 non-null  float64
#  25  pNN25              369289 non-null  float64
#  26  pNN50              369289 non-null  float64
#  27  KURT               369289 non-null  float64
#  28  SKEW               369289 non-null  float64
#  29  MEAN_REL_RR        369289 non-null  float64
#  30  MEDIAN_REL_RR      369289 non-null  float64
#  31  SDRR_REL_RR        369289 non-null  float64
#  32  RMSSD_REL_RR       369289 non-null  float64
#  33  SDSD_REL_RR        369289 non-null  float64
#  34  SDRR_RMSSD_REL_RR  369289 non-null  float64
#  35  KURT_REL_RR        369289 non-null  float64
#  36  SKEW_REL_RR        369289 non-null  float64
# dtypes: float64(34), int64(1), object(2)
# memory usage: 107.1+ MB

# %%
df_train = data_train.drop(['uuid'],axis = 1)

# %%
df_train.describe()
# Out:
#                  VLF        VLF_PCT             LF         LF_PCT  \
# count  369289.000000  369289.000000  369289.000000  369289.000000
# mean     2199.580170      64.289242     946.530252      34.095182
# std      1815.773422      16.774844     574.171780      16.040290
# min       159.480176      19.031219      90.048557       2.165119
# 25%      1001.189280      52.909877     545.449386      22.305936
# 50%      1667.903111      66.350237     782.716291      32.047025
# 75%      2654.121052      76.825032    1201.432256      44.647115
# max     12617.977191      97.738848    3291.548112      77.928847
#
#                LF_NU             HF         HF_PCT          HF_NU  \
# count  369289.000000  369289.000000  369289.000000  369289.000000
# mean       95.566718      39.245603       1.615576       4.433282
# std         4.123365      45.398869       1.761073       4.123365
# min        69.879083       0.061783       0.002150       0.012825
# 25%        93.645734      10.720312       0.346803       1.228054
# 50%        96.643140      24.841938       1.039513       3.356860
# 75%        98.771946      45.272368       2.245115       6.354266
# max        99.987175     364.486936      13.095664      30.120917
#
#                   TP          LF_HF  ...           KURT           SKEW  \
# count  369289.000000  369289.000000  ...  369289.000000  369289.000000
# mean     3185.356025     115.977200  ...       0.523235       0.041628
# std      1923.227187     360.855129  ...       1.790348       0.699522
# min       377.692795       2.319952  ...      -1.894820      -2.136278
# 25%      1828.147788      14.737458  ...      -0.352783      -0.359291
# 50%      2796.856587      28.789747  ...       0.040736      -0.060966
# 75%      4052.260157      80.429614  ...       0.722833       0.282417
# max     13390.684098    7796.443096  ...      64.088107       6.777800
#
#         MEAN_REL_RR  MEDIAN_REL_RR    SDRR_REL_RR   RMSSD_REL_RR  \
# count  3.692890e+05  369289.000000  369289.000000  369289.000000
# mean  -1.756602e-06      -0.000465       0.018571       0.009701
# std    1.630256e-04       0.000868       0.005455       0.003897
# min   -1.233914e-03      -0.004425       0.008987       0.003220
# 25%   -7.280000e-05      -0.000917       0.014261       0.006984
# 50%   -9.330000e-07      -0.000312       0.017318       0.008691
# 75%    6.910000e-05       0.000131       0.021827       0.011460
# max    1.244098e-03       0.002095       0.036571       0.026955
#
#          SDSD_REL_RR  SDRR_RMSSD_REL_RR    KURT_REL_RR    SKEW_REL_RR
# count  369289.000000      369289.000000  369289.000000  369289.000000
# mean        0.009701           2.006817       0.523235       0.041628
# std         0.003897           0.375845       1.790348       0.699522
# min         0.003220           1.169342      -1.894820      -2.136278
# 25%         0.006984           1.749801      -0.352783      -0.359291
# 50%         0.008691           1.934416       0.040736      -0.060966
# 75%         0.011460           2.221232       0.722833       0.282417
# max         0.026955           3.724134      64.088107       6.777800
#
# [8 rows x 35 columns]

# %%
def missing_check(df):
    total = df.isnull().sum().sort_values(ascending=False)   # total number of null values
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)  # percentage of values that are null
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  # putting the above two together
    return missing_data # return the dataframe
missing_check(df_train)
# Out:
#                    Total  Percent
# SKEW_REL_RR            0      0.0
# KURT_REL_RR            0      0.0
# datasetId              0      0.0
# higuci                 0      0.0
# sampen                 0      0.0
# SD2                    0      0.0
# SD1                    0      0.0
# HF_LF                  0      0.0
# LF_HF                  0      0.0
# TP                     0      0.0
# HF_NU                  0      0.0
# HF_PCT                 0      0.0
# HF                     0      0.0
# LF_NU                  0      0.0
# LF_PCT                 0      0.0
# LF                     0      0.0
# VLF_PCT                0      0.0
# condition              0      0.0
# MEAN_RR                0      0.0
# MEDIAN_RR              0      0.0
# SKEW                   0      0.0
# SDRR_RMSSD_REL_RR      0      0.0
# SDSD_REL_RR            0      0.0
# RMSSD_REL_RR           0      0.0
# SDRR_REL_RR            0      0.0
# MEDIAN_REL_RR          0      0.0
# MEAN_REL_RR            0      0.0
# KURT                   0      0.0
# SDRR                   0      0.0
# pNN50                  0      0.0
# pNN25                  0      0.0
# HR                     0      0.0
# SDRR_RMSSD             0      0.0
# SDSD                   0      0.0
# RMSSD                  0      0.0
# VLF                    0      0.0

# %%
## User defined function to calculate statistics for the attributes
def stats_measure(x):
  print('Number of Unique Values')
  print(x.nunique())
  print(" ")
  print('Summary of the attribute')
  print(x.describe())
  print(" ")
  print('Skewness of the attribute')
  if x.dtype=='O':
    print('Categorical Variable')
  else:
    print(x.skew())
  print(" ")
  print('Kurtosis of the attribute')
  if x.dtype=='O':
    print('Categorical Variable')
  else:
    print(x.kurt())

# %%
for p in df_train.columns:
  print('-'*100)  
  print(f'Statistical Measures of the attribute: ',p)
  col = df_train[p]
  stats_measure(col)
  print('-'*100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  VLF
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean       2199.580170
# std        1815.773422
# min         159.480176
# 25%        1001.189280
# 50%        1667.903111
# 75%        2654.121052
# max       12617.977191
# Name: VLF, dtype: float64
#
# Skewness of the attribute
# 1.9607349536265608
#
# Kurtosis of the attribute
# 4.493563049525889
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  VLF_PCT
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean         64.289242
# std          16.774844
# min          19.031219
# 25%          52.909877
# 50%          66.350237
# 75%          76.825032
# max          97.738848
# Name: VLF_PCT, dtype: float64
#
# Skewness of the attribute
# -0.4108357400753111
#
# Kurtosis of the attribute
# -0.5209713606084594
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  LF
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean        946.530252
# std         574.171780
# min          90.048557
# 25%         545.449386
# 50%         782.716291
# 75%        1201.432256
# max        3291.548112
# Name: LF, dtype: float64
#
# Skewness of the attribute
# 1.3490757195715615
#
# Kurtosis of the attribute
# 1.7392233142710491
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  LF_PCT
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean         34.095182
# std          16.040290
# min           2.165119
# 25%          22.305936
# 50%          32.047025
# 75%          44.647115
# max          77.928847
# Name: LF_PCT, dtype: float64
#
# Skewness of the attribute
# 0.4251638698749863
#
# Kurtosis of the attribute
# -0.48905152820432507
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  LF_NU
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean         95.566718
# std           4.123365
# min          69.879083
# 25%          93.645734
# 50%          96.643140
# 75%          98.771946
# max          99.987175
# Name: LF_NU, dtype: float64
#
# Skewness of the attribute
# -1.6456029928794356
#
# Kurtosis of the attribute
# 3.852707180104897
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  HF
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean         39.245603
# std          45.398869
# min           0.061783
# 25%          10.720312
# 50%          24.841938
# 75%          45.272368
# max         364.486936
# Name: HF, dtype: float64
#
# Skewness of the attribute
# 2.47652972022444
#
# Kurtosis of the attribute
# 7.961637254185358
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  HF_PCT
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean          1.615576
# std           1.761073
# min           0.002150
# 25%           0.346803
# 50%           1.039513
# 75%           2.245115
# max          13.095664
# Name: HF_PCT, dtype: float64
#
# Skewness of the attribute
# 2.0218822039608204
#
# Kurtosis of the attribute
# 5.517448861469981
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  HF_NU
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean          4.433282
# std           4.123365
# min           0.012825
# 25%           1.228054
# 50%           3.356860
# 75%           6.354266
# max          30.120917
# Name: HF_NU, dtype: float64
#
# Skewness of the attribute
# 1.6456029928794451
#
# Kurtosis of the attribute
# 3.852707180104919
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  TP
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean       3185.356025
# std        1923.227187
# min         377.692795
# 25%        1828.147788
# 50%        2796.856587
# 75%        4052.260157
# max       13390.684098
# Name: TP, dtype: float64
#
# Skewness of the attribute
# 1.4524353635978386
#
# Kurtosis of the attribute
# 2.8137120724874656
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  LF_HF
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean        115.977200
# std         360.855129
# min           2.319952
# 25%          14.737458
# 50%          28.789747
# 75%          80.429614
# max        7796.443096
# Name: LF_HF, dtype: float64
#
# Skewness of the attribute
# 9.781091333181752
#
# Kurtosis of the attribute
# 133.475215416446
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  HF_LF
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean          0.048506
# std           0.049238
# min           0.000128
# 25%           0.012433
# 50%           0.034735
# 75%           0.067854
# max           0.431043
# Name: HF_LF, dtype: float64
#
# Skewness of the attribute
# 2.159372294236695
#
# Kurtosis of the attribute
# 7.293164561496808
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SD1
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean         10.593708
# std           2.914795
# min           3.911344
# 25%           8.368340
# 50%          10.196621
# 75%          12.679005
# max          18.836107
# Name: SD1, dtype: float64
#
# Skewness of the attribute
# 0.39966842991188156
#
# Kurtosis of the attribute
# -0.5595508508953251
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SD2
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean        154.178997
# std         109.170222
# min          38.307745
# 25%          90.326864
# 50%         116.221063
# 75%         166.764850
# max         796.852945
# Name: SD2, dtype: float64
#
# Skewness of the attribute
# 2.3633863715930166
#
# Kurtosis of the attribute
# 6.374008137909192
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  sampen
# Number of Unique Values
# 82511
#
# Summary of the attribute
# count    369289.000000
# mean          2.062471
# std           0.206999
# min           0.434576
# 25%           2.032977
# 50%           2.134214
# 75%           2.181929
# max           2.234841
# Name: sampen, dtype: float64
#
# Skewness of the attribute
# -3.0910120903545772
#
# Kurtosis of the attribute
# 12.79041699385105
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  higuci
# Number of Unique Values
# 369289
#
# Summary of the attribute
# count    369289.000000
# mean          1.182292
# std           0.062192
# min           1.033984
# 25%           1.139929
# 50%           1.174293
# 75%           1.223621
# max           1.361219
# Name: higuci, dtype: float64
#
# Skewness of the attribute
# 0.335008119436041
#
# Kurtosis of the attribute
# -0.2788429775301653
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  datasetId
# Number of Unique Values
# 1
#
# Summary of the attribute
# count    369289.0
# mean          2.0
# std           0.0
# min           2.0
# 25%           2.0
# 50%           2.0
# 75%           2.0
# max           2.0
# Name: datasetId, dtype: float64
#
# Skewness of the attribute
# 0
#
# Kurtosis of the attribute
# 0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  condition
# Number of Unique Values
# 3
#
# Summary of the attribute
# count        369289
# unique            3
# top       no stress
# freq         200082
# Name: condition, dtype: object
#
# Skewness of the attribute
# Categorical Variable
#
# Kurtosis of the attribute
# Categorical Variable
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  MEAN_RR
# Number of Unique Values
# 369264
#
# Summary of the attribute
# count    369289.000000
# mean        846.650104
# std         124.603984
# min         547.492221
# 25%         760.228533
# 50%         822.951438
# 75%         924.117422
# max        1322.016957
# Name: MEAN_RR, dtype: float64
#
# Skewness of the attribute
# 0.6479996930953484
#
# Kurtosis of the attribute
# 0.43438216257955586
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  MEDIAN_RR
# Number of Unique Values
# 106316
#
# Summary of the attribute
# count    369289.000000
# mean        841.965890
# std         132.321005
# min         517.293295
# 25%         755.750735
# 50%         819.689595
# 75%         916.821570
# max        1653.122250
# Name: MEDIAN_RR, dtype: float64
#
# Skewness of the attribute
# 0.925513427975939
#
# Kurtosis of the attribute
# 2.6459329796248996
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDRR
# Number of Unique Values
# 369274
#
# Summary of the attribute
# count    369289.000000
# mean        109.352531
# std          77.117025
# min          27.233947
# 25%          64.205641
# 50%          82.608243
# 75%         118.237002
# max         563.486949
# Name: SDRR, dtype: float64
#
# Skewness of the attribute
# 2.3637886003972968
#
# Kurtosis of the attribute
# 6.380031142173713
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  RMSSD
# Number of Unique Values
# 369240
#
# Summary of the attribute
# count    369289.000000
# mean         14.977498
# std           4.120766
# min           5.529742
# 25%          11.830959
# 50%          14.415918
# 75%          17.927144
# max          26.629477
# Name: RMSSD, dtype: float64
#
# Skewness of the attribute
# 0.3995293595786794
#
# Kurtosis of the attribute
# -0.5598191884993997
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDSD
# Number of Unique Values
# 369240
#
# Summary of the attribute
# count    369289.000000
# mean         14.976767
# std           4.120768
# min           5.529630
# 25%          11.830671
# 50%          14.415388
# 75%          17.924839
# max          26.629392
# Name: SDSD, dtype: float64
#
# Skewness of the attribute
# 0.39966842991281837
#
# Kurtosis of the attribute
# -0.5595508508912301
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDRR_RMSSD
# Number of Unique Values
# 369283
#
# Summary of the attribute
# count    369289.000000
# mean          7.396597
# std           5.143834
# min           2.660381
# 25%           4.541896
# 50%           5.952112
# 75%           7.919841
# max          54.523950
# Name: SDRR_RMSSD, dtype: float64
#
# Skewness of the attribute
# 3.7079392238923794
#
# Kurtosis of the attribute
# 21.348856630885198
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  HR
# Number of Unique Values
# 369268
#
# Summary of the attribute
# count    369289.000000
# mean         73.941824
# std          10.337453
# min          48.737243
# 25%          66.715776
# 50%          74.217809
# 75%          80.334937
# max         113.752308
# Name: HR, dtype: float64
#
# Skewness of the attribute
# 0.411721101877781
#
# Kurtosis of the attribute
# 0.42982813815597787
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  pNN25
# Number of Unique Values
# 592
#
# Summary of the attribute
# count    369289.000000
# mean          9.841143
# std           8.195574
# min           0.000000
# 25%           3.666667
# 50%           7.600000
# 75%          13.333333
# max          39.400000
# Name: pNN25, dtype: float64
#
# Skewness of the attribute
# 1.2031139762188012
#
# Kurtosis of the attribute
# 0.8497929032667919
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  pNN50
# Number of Unique Values
# 83
#
# Summary of the attribute
# count    369289.000000
# mean          0.866001
# std           0.990189
# min           0.000000
# 25%           0.000000
# 50%           0.466667
# 75%           1.466667
# max           5.466667
# Name: pNN50, dtype: float64
#
# Skewness of the attribute
# 1.2641368713477086
#
# Kurtosis of the attribute
# 1.0252748582390554
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  KURT
# Number of Unique Values
# 369256
#
# Summary of the attribute
# count    369289.000000
# mean          0.523235
# std           1.790348
# min          -1.894820
# 25%          -0.352783
# 50%           0.040736
# 75%           0.722833
# max          64.088107
# Name: KURT, dtype: float64
#
# Skewness of the attribute
# 5.722208614516514
#
# Kurtosis of the attribute
# 85.18469349343007
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SKEW
# Number of Unique Values
# 369251
#
# Summary of the attribute
# count    369289.000000
# mean          0.041628
# std           0.699522
# min          -2.136278
# 25%          -0.359291
# 50%          -0.060966
# 75%           0.282417
# max           6.777800
# Name: SKEW, dtype: float64
#
# Skewness of the attribute
# 1.2230045888738652
#
# Kurtosis of the attribute
# 3.487345099700394
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  MEAN_REL_RR
# Number of Unique Values
# 122009
#
# Summary of the attribute
# count    3.692890e+05
# mean    -1.756602e-06
# std      1.630256e-04
# min     -1.233914e-03
# 25%     -7.280000e-05
# 50%     -9.330000e-07
# 75%      6.910000e-05
# max      1.244098e-03
# Name: MEAN_REL_RR, dtype: float64
#
# Skewness of the attribute
# 0.11279587677124324
#
# Kurtosis of the attribute
# 5.215672950533857
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  MEDIAN_REL_RR
# Number of Unique Values
# 23750
#
# Summary of the attribute
# count    369289.000000
# mean         -0.000465
# std           0.000868
# min          -0.004425
# 25%          -0.000917
# 50%          -0.000312
# 75%           0.000131
# max           0.002095
# Name: MEDIAN_REL_RR, dtype: float64
#
# Skewness of the attribute
# -0.9480095020537085
#
# Kurtosis of the attribute
# 1.2695207228141276
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDRR_REL_RR
# Number of Unique Values
# 364727
#
# Summary of the attribute
# count    369289.000000
# mean          0.018571
# std           0.005455
# min           0.008987
# 25%           0.014261
# 50%           0.017318
# 75%           0.021827
# max           0.036571
# Name: SDRR_REL_RR, dtype: float64
#
# Skewness of the attribute
# 0.8695427265054807
#
# Kurtosis of the attribute
# 0.1864329456764655
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  RMSSD_REL_RR
# Number of Unique Values
# 361757
#
# Summary of the attribute
# count    369289.000000
# mean          0.009701
# std           0.003897
# min           0.003220
# 25%           0.006984
# 50%           0.008691
# 75%           0.011460
# max           0.026955
# Name: RMSSD_REL_RR, dtype: float64
#
# Skewness of the attribute
# 1.2587841013131846
#
# Kurtosis of the attribute
# 1.4342180321194151
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDSD_REL_RR
# Number of Unique Values
# 361469
#
# Summary of the attribute
# count    369289.000000
# mean          0.009701
# std           0.003897
# min           0.003220
# 25%           0.006984
# 50%           0.008691
# 75%           0.011460
# max           0.026955
# Name: SDSD_REL_RR, dtype: float64
#
# Skewness of the attribute
# 1.2587844625698343
#
# Kurtosis of the attribute
# 1.4342211716786126
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SDRR_RMSSD_REL_RR
# Number of Unique Values
# 369216
#
# Summary of the attribute
# count    369289.000000
# mean          2.006817
# std           0.375845
# min           1.169342
# 25%           1.749801
# 50%           1.934416
# 75%           2.221232
# max           3.724134
# Name: SDRR_RMSSD_REL_RR, dtype: float64
#
# Skewness of the attribute
# 0.8385868181145948
#
# Kurtosis of the attribute
# 0.8374698960275069
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  KURT_REL_RR
# Number of Unique Values
# 369256
#
# Summary of the attribute
# count    369289.000000
# mean          0.523235
# std           1.790348
# min          -1.894820
# 25%          -0.352783
# 50%           0.040736
# 75%           0.722833
# max          64.088107
# Name: KURT_REL_RR, dtype: float64
#
# Skewness of the attribute
# 5.722208614516514
#
# Kurtosis of the attribute
# 85.18469349343007
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# Statistical Measures of the attribute:  SKEW_REL_RR
# Number of Unique Values
# 369251
#
# Summary of the attribute
# count    369289.000000
# mean          0.041628
# std           0.699522
# min          -2.136278
# 25%          -0.359291
# 50%          -0.060966
# 75%           0.282417
# max           6.777800
# Name: SKEW_REL_RR, dtype: float64
#
# Skewness of the attribute
# 1.2230045888738652
#
# Kurtosis of the attribute
# 3.487345099700394
# ----------------------------------------------------------------------------------------------------

# %%
# List the numerical and categorical columns
numeric_cols = df_train.select_dtypes(include = [np.number]).columns.tolist()
categorical_cols = df_train.select_dtypes(include = [np.object]).columns.tolist()
print('The numeric attributes are:', numeric_cols)
print('The categorical attributes are:', categorical_cols)
# Out:
# The numeric attributes are: ['VLF', 'VLF_PCT', 'LF', 'LF_PCT', 'LF_NU', 'HF', 'HF_PCT', 'HF_NU', 'TP', 'LF_HF', 'HF_LF', 'SD1', 'SD2', 'sampen', 'higuci', 'datasetId', 'MEAN_RR', 'MEDIAN_RR', 'SDRR', 'RMSSD', 'SDSD', 'SDRR_RMSSD', 'HR', 'pNN25', 'pNN50', 'KURT', 'SKEW', 'MEAN_REL_RR', 'MEDIAN_REL_RR', 'SDRR_REL_RR', 'RMSSD_REL_RR', 'SDSD_REL_RR', 'SDRR_RMSSD_REL_RR', 'KURT_REL_RR', 'SKEW_REL_RR']
# The categorical attributes are: ['condition']

# %%
df_train['condition'].value_counts()
# Out:
# no stress        200082
# interruption     105150
# time pressure     64057
# Name: condition, dtype: int64

# %%
dummy_var = pd.get_dummies(df_train['condition'],drop_first = True)
dummy_var.head()
# Out:
#    no stress  time pressure
# 0          1              0
# 1          0              0
# 2          0              0
# 3          1              0
# 4          1              0

# %%
df_train = pd.concat([df_train, dummy_var], axis = 1)
df_train = df_train.drop('condition', axis = 1)

# %%
df_train.head()
# Out:
#            VLF    VLF_PCT           LF     LF_PCT      LF_NU         HF  \
# 0  2661.894136  72.203287  1009.249419  27.375666  98.485263  15.522603
# 1  2314.265450  76.975728   690.113275  22.954139  99.695397   2.108525
# 2  1373.887112  51.152225  1298.222619  48.335104  98.950472  13.769729
# 3  2410.357408  70.180308  1005.981659  29.290305  98.224706  18.181913
# 4  1151.177330  43.918366  1421.782051  54.242160  96.720007  48.215822
#
#      HF_PCT     HF_NU           TP       LF_HF  ...  MEAN_REL_RR  \
# 0  0.421047  1.514737  3686.666157   65.018055  ...    -0.000203
# 1  0.070133  0.304603  3006.487251  327.296635  ...    -0.000059
# 2  0.512671  1.049528  2685.879461   94.280910  ...    -0.000011
# 3  0.529387  1.775294  3434.520980   55.328701  ...     0.000112
# 4  1.839473  3.279993  2621.175204   29.487873  ...    -0.000100
#
#    MEDIAN_REL_RR  SDRR_REL_RR  RMSSD_REL_RR  SDSD_REL_RR  SDRR_RMSSD_REL_RR  \
# 0      -0.000179     0.017080      0.007969     0.007969           2.143342
# 1       0.000611     0.013978      0.004769     0.004769           2.930855
# 2      -0.000263     0.018539      0.008716     0.008716           2.127053
# 3       0.000494     0.017761      0.008660     0.008660           2.050988
# 4      -0.002736     0.023715      0.013055     0.013055           1.816544
#
#    KURT_REL_RR  SKEW_REL_RR  no stress  time pressure
# 0    -0.856554     0.335218          1              0
# 1    -0.408190    -0.155286          0              0
# 2     0.351789    -0.656813          0              0
# 3    -0.504947    -0.386138          1              0
# 4    -0.548408    -0.154252          1              0
#
# [5 rows x 37 columns]

# %%
df_train_imputed = df_train.copy(deep = True)

# %%
for col in numeric_cols:
    Q3 = df_train_imputed[col].quantile(0.75)
    Q1 = df_train_imputed[col].quantile(0.25)
    IQR = Q3 - Q1
    upper_lim = Q3 + (3 * IQR)
    lower_lim = Q1 - (3 * IQR)
    df_train_imputed.loc[(df_train_imputed[col] < lower_lim) | (df_train_imputed[col] > upper_lim), col] = df_train_imputed[col].median()

#df_train_imputed.isnull().sum()

# %%
# Using SimpleImputer to fill missing values by median
print('Descriptive Stats before handling outliers: \n', '--'*30)
display(df_train.describe().T)

print('Descriptive Stats after handling outliers: \n', '--'*30)
display(df_train_imputed.describe().T)
# Out:
# Descriptive Stats before handling outliers:
#  ------------------------------------------------------------
#                       count         mean          std         min  \
# VLF                369289.0  2199.580170  1815.773422  159.480176
# VLF_PCT            369289.0    64.289242    16.774844   19.031219
# LF                 369289.0   946.530252   574.171780   90.048557
# LF_PCT             369289.0    34.095182    16.040290    2.165119
# LF_NU              369289.0    95.566718     4.123365   69.879083
# HF                 369289.0    39.245603    45.398869    0.061783
# HF_PCT             369289.0     1.615576     1.761073    0.002150
# HF_NU              369289.0     4.433282     4.123365    0.012825
# TP                 369289.0  3185.356025  1923.227187  377.692795
# LF_HF              369289.0   115.977200   360.855129    2.319952
# HF_LF              369289.0     0.048506     0.049238    0.000128
# SD1                369289.0    10.593708     2.914795    3.911344
# SD2                369289.0   154.178997   109.170222   38.307745
# sampen             369289.0     2.062471     0.206999    0.434576
# higuci             369289.0     1.182292     0.062192    1.033984
# datasetId          369289.0     2.000000     0.000000    2.000000
# MEAN_RR            369289.0   846.650104   124.603984  547.492221
# MEDIAN_RR          369289.0   841.965890   132.321005  517.293295
# SDRR               369289.0   109.352531    77.117025   27.233947
# RMSSD              369289.0    14.977498     4.120766    5.529742
# SDSD               369289.0    14.976767     4.120768    5.529630
# SDRR_RMSSD         369289.0     7.396597     5.143834    2.660381
# HR                 369289.0    73.941824    10.337453   48.737243
# pNN25              369289.0     9.841143     8.195574    0.000000
# pNN50              369289.0     0.866001     0.990189    0.000000
# KURT               369289.0     0.523235     1.790348   -1.894820
# SKEW               369289.0     0.041628     0.699522   -2.136278
# MEAN_REL_RR        369289.0    -0.000002     0.000163   -0.001234
# MEDIAN_REL_RR      369289.0    -0.000465     0.000868   -0.004425
# SDRR_REL_RR        369289.0     0.018571     0.005455    0.008987
# RMSSD_REL_RR       369289.0     0.009701     0.003897    0.003220
# SDSD_REL_RR        369289.0     0.009701     0.003897    0.003220
# SDRR_RMSSD_REL_RR  369289.0     2.006817     0.375845    1.169342
# KURT_REL_RR        369289.0     0.523235     1.790348   -1.894820
# SKEW_REL_RR        369289.0     0.041628     0.699522   -2.136278
# no stress          369289.0     0.541803     0.498250    0.000000
# time pressure      369289.0     0.173460     0.378645    0.000000
#
#                            25%           50%          75%           max
# VLF                1001.189280  1.667903e+03  2654.121052  12617.977191
# VLF_PCT              52.909877  6.635024e+01    76.825032     97.738848
# LF                  545.449386  7.827163e+02  1201.432256   3291.548112
# LF_PCT               22.305936  3.204703e+01    44.647115     77.928847
# LF_NU                93.645734  9.664314e+01    98.771946     99.987175
# HF                   10.720312  2.484194e+01    45.272368    364.486936
# HF_PCT                0.346803  1.039513e+00     2.245115     13.095664
# HF_NU                 1.228054  3.356860e+00     6.354266     30.120917
# TP                 1828.147788  2.796857e+03  4052.260157  13390.684098
# LF_HF                14.737458  2.878975e+01    80.429614   7796.443096
# HF_LF                 0.012433  3.473459e-02     0.067854      0.431043
# SD1                   8.368340  1.019662e+01    12.679005     18.836107
# SD2                  90.326864  1.162211e+02   166.764850    796.852945
# sampen                2.032977  2.134214e+00     2.181929      2.234841
# higuci                1.139929  1.174293e+00     1.223621      1.361219
# datasetId             2.000000  2.000000e+00     2.000000      2.000000
# MEAN_RR             760.228533  8.229514e+02   924.117422   1322.016957
# MEDIAN_RR           755.750735  8.196896e+02   916.821570   1653.122250
# SDRR                 64.205641  8.260824e+01   118.237002    563.486949
# RMSSD                11.830959  1.441592e+01    17.927144     26.629477
# SDSD                 11.830671  1.441539e+01    17.924839     26.629392
# SDRR_RMSSD            4.541896  5.952112e+00     7.919841     54.523950
# HR                   66.715776  7.421781e+01    80.334937    113.752308
# pNN25                 3.666667  7.600000e+00    13.333333     39.400000
# pNN50                 0.000000  4.666667e-01     1.466667      5.466667
# KURT                 -0.352783  4.073621e-02     0.722833     64.088107
# SKEW                 -0.359291 -6.096592e-02     0.282417      6.777800
# MEAN_REL_RR          -0.000073 -9.330000e-07     0.000069      0.001244
# MEDIAN_REL_RR        -0.000917 -3.116070e-04     0.000131      0.002095
# SDRR_REL_RR           0.014261  1.731795e-02     0.021827      0.036571
# RMSSD_REL_RR          0.006984  8.690833e-03     0.011460      0.026955
# SDSD_REL_RR           0.006984  8.690797e-03     0.011460      0.026955
# SDRR_RMSSD_REL_RR     1.749801  1.934416e+00     2.221232      3.724134
# KURT_REL_RR          -0.352783  4.073621e-02     0.722833     64.088107
# SKEW_REL_RR          -0.359291 -6.096592e-02     0.282417      6.777800
# no stress             0.000000  1.000000e+00     1.000000      1.000000
# time pressure         0.000000  0.000000e+00     0.000000      1.000000
# Descriptive Stats after handling outliers:
#  ------------------------------------------------------------
#                       count         mean          std         min  \
# VLF                369289.0  2005.718669  1426.877298  159.480176
# VLF_PCT            369289.0    64.289242    16.774844   19.031219
# LF                 369289.0   944.821855   571.037542   90.048557
# LF_PCT             369289.0    34.095182    16.040290    2.165119
# LF_NU              369289.0    95.698710     3.805403   78.269762
# HF                 369289.0    33.564026    32.819622    0.061783
# HF_PCT             369289.0     1.508332     1.508504    0.002150
# HF_NU              369289.0     4.301290     3.805403    0.012825
# TP                 369289.0  3147.309366  1836.098125  377.692795
# LF_HF              369289.0    47.087608    53.973996    2.319952
# HF_LF              369289.0     0.045509     0.041330    0.000128
# SD1                369289.0    10.593708     2.914795    3.911344
# SD2                369289.0   131.886007    65.151164   38.307745
# sampen             369289.0     2.094604     0.127432    1.586136
# higuci             369289.0     1.182292     0.062192    1.033984
# datasetId          369289.0     2.000000     0.000000    2.000000
# MEAN_RR            369289.0   846.650104   124.603984  547.492221
# MEDIAN_RR          369289.0   840.350084   127.514551  517.293295
# SDRR               369289.0    93.621181    46.038497   27.233947
# RMSSD              369289.0    14.977498     4.120766    5.529742
# SDSD               369289.0    14.976767     4.120768    5.529630
# SDRR_RMSSD         369289.0     6.556510     2.972724    2.660381
# HR                 369289.0    73.941824    10.337453   48.737243
# pNN25              369289.0     9.841143     8.195574    0.000000
# pNN50              369289.0     0.866001     0.990189    0.000000
# KURT               369289.0     0.221431     0.911141   -1.894820
# SKEW               369289.0    -0.001269     0.614143   -2.136278
# MEAN_REL_RR        369289.0    -0.000003     0.000133   -0.000498
# MEDIAN_REL_RR      369289.0    -0.000458     0.000853   -0.004043
# SDRR_REL_RR        369289.0     0.018571     0.005455    0.008987
# RMSSD_REL_RR       369289.0     0.009663     0.003822    0.003220
# SDSD_REL_RR        369289.0     0.009663     0.003822    0.003220
# SDRR_RMSSD_REL_RR  369289.0     2.005863     0.373817    1.169342
# KURT_REL_RR        369289.0     0.221431     0.911141   -1.894820
# SKEW_REL_RR        369289.0    -0.001269     0.614143   -2.136278
# no stress          369289.0     0.541803     0.498250    0.000000
# time pressure      369289.0     0.173460     0.378645    0.000000
#
#                            25%           50%          75%           max
# VLF                1001.189280  1.667903e+03  2496.617475   7612.783844
# VLF_PCT              52.909877  6.635024e+01    76.825032     97.738848
# LF                  545.449386  7.827163e+02  1199.536481   3169.378593
# LF_PCT               22.305936  3.204703e+01    44.647115     77.928847
# LF_NU                93.729698  9.664314e+01    98.771946     99.987175
# HF                   10.720312  2.484194e+01    41.551803    148.921411
# HF_PCT                0.346803  1.039513e+00     2.137243      7.938278
# HF_NU                 1.228054  3.356860e+00     6.270302     21.730238
# TP                 1828.147788  2.796857e+03  4024.752713  10724.569836
# LF_HF                14.737458  2.878975e+01    52.132280    277.505613
# HF_LF                 0.012433  3.473459e-02     0.066045      0.234043
# SD1                   8.368340  1.019662e+01    12.679005     18.836107
# SD2                  90.326864  1.162211e+02   150.496361    396.063135
# sampen                2.055405  2.134214e+00     2.181929      2.234841
# higuci                1.139929  1.174293e+00     1.223621      1.361219
# datasetId             2.000000  2.000000e+00     2.000000      2.000000
# MEAN_RR             760.228533  8.229514e+02   924.117422   1322.016957
# MEDIAN_RR           755.750735  8.196896e+02   915.355805   1398.690800
# SDRR                 64.205641  8.260824e+01   106.725108    280.326586
# RMSSD                11.830959  1.441592e+01    17.927144     26.629477
# SDSD                 11.830671  1.441539e+01    17.924839     26.629392
# SDRR_RMSSD            4.541896  5.952112e+00     7.450486     18.053488
# HR                   66.715776  7.421781e+01    80.334937    113.752308
# pNN25                 3.666667  7.600000e+00    13.333333     39.400000
# pNN50                 0.000000  4.666667e-01     1.466667      5.466667
# KURT                 -0.352783  4.073621e-02     0.541449      3.949466
# SKEW                 -0.359291 -6.096592e-02     0.243673      2.207513
# MEAN_REL_RR          -0.000069 -9.330000e-07     0.000065      0.000495
# MEDIAN_REL_RR        -0.000911 -3.116070e-04     0.000131      0.002095
# SDRR_REL_RR           0.014261  1.731795e-02     0.021827      0.036571
# RMSSD_REL_RR          0.006984  8.690833e-03     0.011413      0.024881
# SDSD_REL_RR           0.006984  8.690797e-03     0.011413      0.024881
# SDRR_RMSSD_REL_RR     1.749801  1.934416e+00     2.220362      3.634293
# KURT_REL_RR          -0.352783  4.073621e-02     0.541449      3.949466
# SKEW_REL_RR          -0.359291 -6.096592e-02     0.243673      2.207513
# no stress             0.000000  1.000000e+00     1.000000      1.000000
# time pressure         0.000000  0.000000e+00     0.000000      1.000000

# %%
# Splitting the dataset into the Training and Test sets 
from sklearn.model_selection import train_test_split
X = df_train.drop(['HR'],axis = 1)
y = df_train['HR']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((258502, 36), (110787, 36), (258502,), (110787,))

# %%
## Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)
X_train = pd.DataFrame(X_train, columns = X.columns)
X_test = pd.DataFrame(X_test, columns = X.columns)

# %%
X_train.head()
# Out:
#         VLF   VLF_PCT        LF    LF_PCT     LF_NU        HF    HF_PCT  \
# 0 -0.337147  0.959736 -1.054647 -1.048462 -1.815251  0.152738  0.408434
# 1 -0.592396 -1.296683  0.902949  1.328997  0.209151  0.331519  0.247530
# 2 -0.368810  1.059505 -1.139790 -1.148010 -1.980925  0.064074  0.364668
# 3  2.223109  1.296993  0.101254 -1.261970  0.906393 -0.709788 -0.862387
# 4 -0.230664 -0.644641  0.714834  0.412462 -1.961633  3.418022  2.389290
#
#       HF_NU        TP     LF_HF  ...  MEAN_REL_RR  MEDIAN_REL_RR  SDRR_REL_RR  \
# 0  1.815251 -0.629175 -0.300201  ...    -0.311869       0.672531    -0.766268
# 1 -0.209151 -0.282537 -0.246284  ...    -1.070697      -2.609775     0.964367
# 2  1.980925 -0.686538 -0.301451  ...    -0.834048       0.360071    -0.848841
# 3 -0.906393  2.113033  0.071285  ...    -0.109317      -0.034040     0.009207
# 4  1.961633  0.075501 -0.301313  ...    -0.706962       0.734184     1.813499
#
#    RMSSD_REL_RR  SDSD_REL_RR  SDRR_RMSSD_REL_RR  KURT_REL_RR  SKEW_REL_RR  \
# 0     -0.070457    -0.070458          -1.276527     2.122184     2.903013
# 1      0.872310     0.872309          -0.498063    -0.597993    -0.281476
# 2     -0.173726    -0.173726          -1.228314     2.787550     3.393158
# 3     -0.709902    -0.709898           1.801348     0.329040    -0.395905
# 4      2.250219     2.250219          -1.237276    -0.483919    -1.140503
#
#    no stress  time pressure
# 0   0.919629      -0.458159
# 1   0.919629      -0.458159
# 2   0.919629      -0.458159
# 3  -1.087395       2.182649
# 4   0.919629      -0.458159
#
# [5 rows x 36 columns]

# %% [markdown]
# ### LR-unimputed

# %%
from sklearn import svm
from sklearn.ensemble import (RandomForestRegressor, GradientBoostingRegressor,AdaBoostRegressor,BaggingRegressor)
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr_model.score(X_test,y_test)
# Out:
# -5.250559028346631e+17

# %%
kfold = KFold(n_splits=10,random_state=42)
results = cross_val_score(lr_model,X,y,cv=kfold)
print(results.mean()*100.0,results.std()*100.0)
# Out:
# C:\Users\kau\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# 98.09214343204381 0.02246981216314609

# %% [markdown]
# But can't rely on LR as the score is -ve.

# %% [markdown]
# ### Random forest regressor - unimputed

# %%
model=RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
from sklearn import metrics
y_pred = model.predict(X_test)
# performance on train data
print('Performance on training data using RFR:',model.score(X_train,y_train))
# performance on test data
print('Performance on testing data using RFR:',model.score(X_test,y_test))
#Evaluate the model using accuracy
acc_RFR=metrics.r2_score(y_test, y_pred)
print('Accuracy DT: ',acc_RFR)
print('MSE: ',metrics.mean_squared_error(y_test, y_pred))
# Out:
# Performance on training data using RFR: 0.9999982767016157
# Performance on testing data using RFR: 0.9998146043562646
# Accuracy DT:  0.9998146043562646
# MSE:  0.01997927012183766

# %%
kfold = KFold(n_splits=10,random_state=42,shuffle=True)
results = cross_val_score(model,X,y,cv=kfold)
print(results.mean()*100.0,results.std()*100.0)

# %% [markdown]
# ### Random forest regressor - imputed

# %%
X_imp = df_train_imputed.drop(['HR'],axis = 1)
y_imp = df_train_imputed['HR']
X_train_imp, X_test_imp, y_train_imp, y_test_imp = train_test_split(X_imp,y_imp,test_size = 0.3, random_state = 42)
X_train_imp.shape, X_test_imp.shape, y_train_imp.shape, y_test_imp.shape
# Out:
# ((258502, 36), (110787, 36), (258502,), (110787,))

# %%
X_train_imp = sc.fit_transform(X_train_imp)
X_test_imp = sc.fit_transform(X_test_imp)
X_train_imp = pd.DataFrame(X_train_imp, columns = X.columns)
X_test_imp = pd.DataFrame(X_test_imp, columns = X.columns)

# %%
model_imp=RandomForestRegressor()
model_imp.fit(X_train_imp, y_train_imp)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
from sklearn import metrics
y_pred_imp = model_imp.predict(X_test_imp)
# performance on train data
print('Performance on training data using RFR:',model_imp.score(X_train_imp,y_train_imp))
# performance on test data
print('Performance on testing data using RFR:',model_imp.score(X_test_imp,y_test_imp))
#Evaluate the model using accuracy
acc_RFR_imp=metrics.r2_score(y_test_imp, y_pred_imp)
print('Accuracy DT: ',acc_RFR_imp)
print('MSE: ',metrics.mean_squared_error(y_test_imp, y_pred_imp))
# Out:
# Performance on training data using RFR: 0.9999987022564398
# Performance on testing data using RFR: 0.9998831751337665
# Accuracy DT:  0.9998831751337665
# MSE:  0.01258970012671195

# %% [markdown]
# ### Linear SVR
# ##### Imputed

# %%
from sklearn.svm import LinearSVR

regr = LinearSVR(random_state=0, tol=1e-5)
regr.fit(X_train,y_train)
# Out:
# C:\Users\kau\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=0, tol=1e-05, verbose=0)

# %%
y_pred = regr.predict(X_test)
# performance on train data
print('Performance on training data using RFR:',regr.score(X_train,y_train))
# performance on test data
print('Performance on testing data using RFR:',regr.score(X_test,y_test))
#Evaluate the model using accuracy
acc_RFR=metrics.r2_score(y_test, y_pred)
print('Accuracy DT: ',acc_RFR)
print('MSE: ',metrics.mean_squared_error(y_test, y_pred))
# Out:
# Performance on training data using RFR: 0.9778520312903042
# Performance on testing data using RFR: 0.9773735572335698
# Accuracy DT:  0.9773735572335698
# MSE:  2.4383518556230284

# %% [markdown]
# ##### imputed

# %%
regr_imp = LinearSVR(random_state=0, tol=1e-5)
regr_imp.fit(X_train_imp,y_train_imp)
# Out:
# C:\Users\kau\Anaconda3\lib\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVR(C=1.0, dual=True, epsilon=0.0, fit_intercept=True,
#           intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#           random_state=0, tol=1e-05, verbose=0)

# %%
y_pred_imp = regr_imp.predict(X_test_imp)
# performance on train data
print('Performance on training data using RFR:',regr_imp.score(X_train_imp,y_train_imp))
# performance on test data
print('Performance on testing data using RFR:',regr_imp.score(X_test_imp,y_test_imp))
#Evaluate the model using accuracy
acc_RFR_imp=metrics.r2_score(y_test_imp, y_pred_imp)
print('Accuracy DT: ',acc_RFR_imp)
print('MSE: ',metrics.mean_squared_error(y_test_imp, y_pred_imp))
# Out:
# Performance on training data using RFR: 0.9679473971511207
# Performance on testing data using RFR: 0.9673769013779434
# Accuracy DT:  0.9673769013779434
# MSE:  3.515647328323491
